# %% [markdown]
# # Practical  No. 4
#
# ## Program/Notebook to deal with missing values, Data Reshping, Filtering, Filtering Data, Merging Data

# %% [markdown]
# ### 1)Dealing with missing values

# %%
#Importing Required Libraries
import pandas as pd
import numpy as np

# %%
#Reding excel File
df  = pd.read_excel("Fees_Data.xlsx")
df.head(8)
# Out:
#    Sr. No      EN No.       Name of the student    Branch  Total Fees
# 0       1  EN23204195     SHINDE GAURAV PRAKASH     CIVIL     10056.0  \
# 1       2  EN23146043   Chaudhari Prasad mahesh        IT         NaN
# 2       3  EN23135942       Borse Gunwant Ashok       NaN     53778.0
# 3       4  EN23135942       Borse Gunwant Ashok  Computer         NaN
# 4       5  EN23119584       Hire Tejas Ravindra  Computer     53778.0
# 5       6  EN23128450  Chaudhari Soham Narendra  Computer     53778.0
# 6       7  EN23128451  Chaudhari Soham Narendra  Computer     53778.0
# 7       8  EN23128452  Chaudhari Soham Narendra  Computer     53778.0
#
#   Fees Paid      Date of payment Mode of Payment      Time
# 0     10056              27/7/23             UPI   2.45 pm  \
# 1       NaN  2023-04-08 00:00:00             UPI  11.40 am
# 2     28778  2023-04-08 00:00:00     Credit Card  11.50 am
# 3     25000  2023-04-08 00:00:00     Credit Card  12:00:00
# ...

# %%
#Replacing NaN Values with other
df['Fees Paid'].fillna(10000, inplace=True)
print(df['Fees Paid'].head(4))
# Out:
# 0    10056
# 1    10000
# 2    28778
# 3    25000
# Name: Fees Paid, dtype: object

# %% [markdown]
# ### Data Reshaping

# %%
#Importing Required Libraries
import pandas as pd
data = pd.read_excel('Fees_Data.xlsx')
data.head()
# Out:
#    Sr. No      EN No.      Name of the student    Branch  Total Fees
# 0       1  EN23204195    SHINDE GAURAV PRAKASH     CIVIL     10056.0  \
# 1       2  EN23146043  Chaudhari Prasad mahesh        IT         NaN
# 2       3  EN23135942      Borse Gunwant Ashok       NaN     53778.0
# 3       4  EN23135942      Borse Gunwant Ashok  Computer         NaN
# 4       5  EN23119584      Hire Tejas Ravindra  Computer     53778.0
#
#   Fees Paid      Date of payment Mode of Payment      Time Status
# 0     10056              27/7/23             UPI   2.45 pm    Yes
# 1       NaN  2023-04-08 00:00:00             UPI  11.40 am    Yes
# 2     28778  2023-04-08 00:00:00     Credit Card  11.50 am     No
# 3     25000  2023-04-08 00:00:00     Credit Card  12:00:00     No
# 4     53778  2023-04-08 00:00:00             UPI  12:10:00    Yes

# %%
data['Status'] = data['Status'].map({'Yes':1, 'No':0}).astype(int)
#data['out'] = data['out'].map({'Yes': 1, 'No': 0}).astype(int)
data.head()
# Out:
#    Sr. No      EN No.      Name of the student    Branch  Total Fees
# 0       1  EN23204195    SHINDE GAURAV PRAKASH     CIVIL     10056.0  \
# 1       2  EN23146043  Chaudhari Prasad mahesh        IT         NaN
# 2       3  EN23135942      Borse Gunwant Ashok       NaN     53778.0
# 3       4  EN23135942      Borse Gunwant Ashok  Computer         NaN
# 4       5  EN23119584      Hire Tejas Ravindra  Computer     53778.0
#
#   Fees Paid      Date of payment Mode of Payment      Time  Status
# 0     10056              27/7/23             UPI   2.45 pm       1
# 1       NaN  2023-04-08 00:00:00             UPI  11.40 am       1
# 2     28778  2023-04-08 00:00:00     Credit Card  11.50 am       0
# 3     25000  2023-04-08 00:00:00     Credit Card  12:00:00       0
# 4     53778  2023-04-08 00:00:00             UPI  12:10:00       1

# %% [markdown]
# ### Filtering Data

# %%
import pandas as pd

# %%
df = pd.read_excel('Cricket.xlsx')
df.head()
# Out:
#    id    name  age  Runs  out
# 0   1   Virat   34    45  Yes
# 1   2   Rohit   36    87  Yes
# 2   3  Hardik   30    40  Yes
# 3   4  Bumrah   39    12  Yes
# 4   5  Jadeja   32    24  Yes

# %%
#Filtering Top runs Scroring Players
df = df[df['Runs'] >= 40]
df
# Out:
#    id    name  age  Runs  out
# 0   1   Virat   34    45  Yes
# 1   2   Rohit   36    87  Yes
# 2   3  Hardik   30    40  Yes
# 5   6    Gill   23    56   No
# 6   7  Kishan   24    46  Yes
# 9  10    Iyer   29    54   No

# %%
#Removing age Column
df = df.drop(['age'], axis=1)
df
# Out:
#    id    name  Runs  out
# 0   1   Virat    45  Yes
# 1   2   Rohit    87  Yes
# 2   3  Hardik    40  Yes
# 5   6    Gill    56   No
# 6   7  Kishan    46  Yes
# 9  10    Iyer    54   No

# %% [markdown]
# ### Merging Data

# %%
import pandas as pd

# %%
Data1 = pd.read_excel('Cricket.xlsx')
Data1.head()
# Out:
#    id    name  age  Runs  out
# 0   1   Virat   34    45  Yes
# 1   2   Rohit   36    87  Yes
# 2   3  Hardik   30    40  Yes
# 3   4  Bumrah   39    12  Yes
# 4   5  Jadeja   32    24  Yes

# %%
Data2  =pd.read_excel('Cricket2.xlsx')
Data2.head()
# Out:
#    id  Sixes  Fours
# 0   1      3      5
# 1   2      4      4
# 2   3      1      3
# 3   4      2      2
# 4   5      1      1

# %%
Data3 = pd.merge(Data1, Data2, on = 'id')
Data3.head()
# Out:
#    id    name  age  Runs  out  Sixes  Fours
# 0   1   Virat   34    45  Yes      3      5
# 1   2   Rohit   36    87  Yes      4      4
# 2   3  Hardik   30    40  Yes      1      3
# 3   4  Bumrah   39    12  Yes      2      2
# 4   5  Jadeja   32    24  Yes      1      1

# %% [markdown]
# ### Subsetting DataFrames in Pandas

# %%
#Import Reuquired Libraries
import pandas as pd

# %%
df = pd.read_excel("Book1.xlsx")
df
# Out:
#     Sr.          EnNo.          Name of Student   CA-I (10marks)
# 0     1  2054491246001    AAKANKSHA ANIL SALUNKE               8  \
# 1     2  2054491246002    ABHINASH KAILASH JOSHI               8
# 2     3  2054491246003      ADITYA JITENDRA MALI               6
# 3     4  2054491246004   AISHWARYA AVINASH PATIL               9
# 4     5  2054491246005      AKSHAY AVINASH PATIL               3
# ..  ...            ...                       ...             ...
# 62   63  2154491246502    LATIKA PRAVIN BHANDARI               8
# 63   64  2154491246503     CHETAN VILAS KHAIRNAR               8
# 64   65  2154491246504  DIVYA LALCHAND CHAUDHARI               8
# 65   66  2154491246505    HARSHIT ARUN GUJARATHI              10
# 66   67  2154491246506   PRANAV SWAPNIL SONAWANE               6
#
#     CA-II (10marks)  Midterm (20marks)   UT1  OEA  Midsem split
# 0                 8                  18    6    8             6
# ...

# %%
#Creating subset  of 1st to 5th rows and columnSr, Enrollment No. , Name of Student
df.iloc[1:5, 0:3]
# Out:
#    Sr.  Enrollment No.         Name of Student
# 1    2   2054491246002   ABHINASH KAILASH JOSHI
# 2    3   2054491246003     ADITYA JITENDRA MALI
# 3    4   2054491246004  AISHWARYA AVINASH PATIL
# 4    5   2054491246005     AKSHAY AVINASH PATIL

# %%
#Creating subset dataframe using indexing operator
df[['Sr.', 'Enrollment No.', 'OEA']].head()
# Out:
#    Sr.  Enrollment No.  OEA
# 0    1   2054491246001    8
# 1    2   2054491246002    8
# 2    3   2054491246003    8
# 3    4   2054491246004    8
# 4    5   2054491246005    8

# %%
#Creating a subset o columns EnNo. and  Name of Student
#Using Filter method()
df.filter(like=En)

# %% [markdown]
# ### Reshaping the Data and Pivot
# *The pivot(index, columns, values) function produces pivot table based on 3 columns of the DataFrame*

# %%
import pandas as pd

# %%
df = pd.read_excel('Fees_Data.xlsx')
df
# Out:
#     Sr. No      EN No.         Name of the student      Branch  Total Fees
# 0        1  EN23204195       SHINDE GAURAV PRAKASH       CIVIL     10056.0  \
# 1        2  EN23146043     Chaudhari Prasad mahesh          IT         NaN
# 2        3  EN23135942         Borse Gunwant Ashok         NaN     53778.0
# 3        4  EN23135942         Borse Gunwant Ashok    Computer         NaN
# 4        5  EN23119584         Hire Tejas Ravindra    Computer     53778.0
# ..     ...         ...                         ...         ...         ...
# 66      67  EN23273933  Ahirrao Leeleshwar Subhash       Civil     53778.0
# 67      68  EN23200937           Gujar Mohit Yatin       Civil     53778.0
# 68      69  EN23117836        Yadav Divya Dadabhai  Electrical     53778.0
# 69      70  EN23247685           Malik Amaan Anwar       Civil     53778.0
# 70      71  EN23237346         Pandey Anjali Anand       Civil     53778.0
#
# ...

# %%
df.pivot(index='EN No.', columns= 'Branch', values= 'Fees Paid')
# Out:
# Branch      NaN CIVIL  Civil     Computer   EE   Electrical     IT Mechanical
# EN No.
# EN23102805  NaN   NaN    NaN          NaN  NaN        53778    NaN        NaN
# EN23103954  NaN   NaN    NaN  43778+10000  NaN          NaN    NaN        NaN
# EN23117836  NaN   NaN    NaN          NaN  NaN        40000    NaN        NaN
# EN23118753  NaN   NaN    NaN          NaN  NaN  43778+10000    NaN        NaN
# EN23119584  NaN   NaN    NaN        53778  NaN          NaN    NaN        NaN
# ...         ...   ...    ...          ...  ...          ...    ...        ...
# EN23254832  NaN   NaN    NaN          NaN  NaN          NaN    NaN      53778
# EN23268026  NaN   NaN  10056          NaN  NaN          NaN    NaN        NaN
# EN23272531  NaN   NaN    NaN          NaN  NaN          NaN  10056        NaN
# EN23273933  NaN   NaN  40000          NaN  NaN          NaN    NaN        NaN
# EN23274997  NaN   NaN    NaN          NaN  NaN          NaN    NaN      10056
#
# [70 rows x 8 columns]

# %% [markdown]
# ### Backfill & Forwardfill

# %%
import pandas as pd

# %%
df = pd.read_excel('Fees_Data.xlsx')
df
# Out:
#     Sr. No      EN No.         Name of the student      Branch  Total Fees
# 0        1  EN23204195       SHINDE GAURAV PRAKASH       CIVIL     10056.0  \
# 1        2  EN23146043     Chaudhari Prasad mahesh          IT         NaN
# 2        3  EN23135942         Borse Gunwant Ashok         NaN     53778.0
# 3        4  EN23135942         Borse Gunwant Ashok    Computer         NaN
# 4        5  EN23119584         Hire Tejas Ravindra    Computer     53778.0
# ..     ...         ...                         ...         ...         ...
# 66      67  EN23273933  Ahirrao Leeleshwar Subhash       Civil     53778.0
# 67      68  EN23200937           Gujar Mohit Yatin       Civil     53778.0
# 68      69  EN23117836        Yadav Divya Dadabhai  Electrical     53778.0
# 69      70  EN23247685           Malik Amaan Anwar       Civil     53778.0
# 70      71  EN23237346         Pandey Anjali Anand       Civil     53778.0
#
# ...

# %%
df.bfill(axis='rows').head()
# Out:
#    Sr. No      EN No.      Name of the student    Branch  Total Fees
# 0       1  EN23204195    SHINDE GAURAV PRAKASH     CIVIL     10056.0  \
# 1       2  EN23146043  Chaudhari Prasad mahesh        IT     53778.0
# 2       3  EN23135942      Borse Gunwant Ashok  Computer     53778.0
# 3       4  EN23135942      Borse Gunwant Ashok  Computer     53778.0
# 4       5  EN23119584      Hire Tejas Ravindra  Computer     53778.0
#
#   Fees Paid      Date of payment Mode of Payment      Time Status
# 0     10056              27/7/23             UPI   2.45 pm    Yes
# 1     28778  2023-04-08 00:00:00             UPI  11.40 am    Yes
# 2     28778  2023-04-08 00:00:00     Credit Card  11.50 am     No
# 3     25000  2023-04-08 00:00:00     Credit Card  12:00:00     No
# 4     53778  2023-04-08 00:00:00             UPI  12:10:00    Yes

# %%
df.ffill(axis='rows').head()
# Out:
#    Sr. No      EN No.      Name of the student    Branch  Total Fees
# 0       1  EN23204195    SHINDE GAURAV PRAKASH     CIVIL     10056.0  \
# 1       2  EN23146043  Chaudhari Prasad mahesh        IT     10056.0
# 2       3  EN23135942      Borse Gunwant Ashok        IT     53778.0
# 3       4  EN23135942      Borse Gunwant Ashok  Computer     53778.0
# 4       5  EN23119584      Hire Tejas Ravindra  Computer     53778.0
#
#   Fees Paid      Date of payment Mode of Payment      Time Status
# 0     10056              27/7/23             UPI   2.45 pm    Yes
# 1     10056  2023-04-08 00:00:00             UPI  11.40 am    Yes
# 2     28778  2023-04-08 00:00:00     Credit Card  11.50 am     No
# 3     25000  2023-04-08 00:00:00     Credit Card  12:00:00     No
# 4     53778  2023-04-08 00:00:00             UPI  12:10:00    Yes

# %%
df.bfill(axis='columns').head()
# Out:
#   Sr. No      EN No.      Name of the student    Branch           Total Fees
# 0      1  EN23204195    SHINDE GAURAV PRAKASH     CIVIL              10056.0  \
# 1      2  EN23146043  Chaudhari Prasad mahesh        IT  2023-04-08 00:00:00
# 2      3  EN23135942      Borse Gunwant Ashok   53778.0              53778.0
# 3      4  EN23135942      Borse Gunwant Ashok  Computer                25000
# 4      5  EN23119584      Hire Tejas Ravindra  Computer              53778.0
#
#              Fees Paid      Date of payment Mode of Payment      Time Status
# 0                10056              27/7/23             UPI   2.45 pm    Yes
# 1  2023-04-08 00:00:00  2023-04-08 00:00:00             UPI  11.40 am    Yes
# 2                28778  2023-04-08 00:00:00     Credit Card  11.50 am     No
# 3                25000  2023-04-08 00:00:00     Credit Card  12:00:00     No
# 4                53778  2023-04-08 00:00:00             UPI  12:10:00    Yes

# %%
df.ffill(axis='columns').head()
# Out:
#   Sr. No      EN No.      Name of the student               Branch Total Fees
# 0      1  EN23204195    SHINDE GAURAV PRAKASH                CIVIL    10056.0  \
# 1      2  EN23146043  Chaudhari Prasad mahesh                   IT         IT
# 2      3  EN23135942      Borse Gunwant Ashok  Borse Gunwant Ashok    53778.0
# 3      4  EN23135942      Borse Gunwant Ashok             Computer   Computer
# 4      5  EN23119584      Hire Tejas Ravindra             Computer    53778.0
#
#   Fees Paid      Date of payment Mode of Payment      Time Status
# 0     10056              27/7/23             UPI   2.45 pm    Yes
# 1        IT  2023-04-08 00:00:00             UPI  11.40 am    Yes
# 2     28778  2023-04-08 00:00:00     Credit Card  11.50 am     No
# 3     25000  2023-04-08 00:00:00     Credit Card  12:00:00     No
# 4     53778  2023-04-08 00:00:00             UPI  12:10:00    Yes
